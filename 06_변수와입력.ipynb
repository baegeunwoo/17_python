# %%
# 변수만들기
## 1. 영문문자, 숫자를 사용
## 2. 대소문자를 구분
## 3. 문자부터 시작을 해야하고, 숫자부터 시작 안됨 a1(O) 1a(X)
## 4. _(밑줄문자)로 시작할 수 있다
## 5. 특수문자(+, -, *, /, % ..)는 사용할 수 없음
## 6. 파이썬 키워드(if, for, while, print)

stand_alone = 1
StandAlone = 1
standAlone = 1
stand-slone = 1 (X)
stand alone = 1 (X)
