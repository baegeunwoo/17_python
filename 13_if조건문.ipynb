# %%
# if 조건문 사용하기

x = 10
if x == 10:
    print("10입니다")

# %%
x = 10

if x == 10:
    print("10입니다")
# Out:
# 10입니다

# %%
# if 조건문에서 코드를 생략하기
x = 10
if x == 10:
    pass

# %%
# if 조건문과 들여쓰기
x = 10
if x==10:
    print('x에 들어있는 숫자는')
        print('10입니다.')
# Out:
#   Cell In[6], line 5
#     print('10입니다.')
#     ^
# IndentationError: unexpected indent

# %%
x = 10
if x==10:
    print('x에 들어있는 숫자는')
print('10입니다.')
# Out:
# x에 들어있는 숫자는
# 10입니다.
