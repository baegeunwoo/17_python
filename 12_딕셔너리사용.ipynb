# %%
#딕셔너리 만들기
# 딕셔너리 = {
# 키1:값1

# }

lux = {
    "health":490,
    "mana":334,
    "melee":550,
    "armor":18.72
}

# %%
lux = {
    "health":490,
    "health":800,
    "mana":334,
    "melee":550,
    "armor":18.72
}

# %%
#dict로 딕셔너리 만들기
lux1 = dict(
    health=490,
    mana=334,
    melee=550,
    armor=18.72
)
lux1
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux2 = dict(zip(['health','mana','melee','armor'],
         [490, 334, 550, 18.72]
))

print(lux2)
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 딕셔너리의 키에 접근하고 값 할당하기
lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

lux['health']
lux["armor"]
# Out:
# 18.72

# %%
lux["health"] = 2037
lux["mana"] = 1104

# %%
lux['mana_regen'] = 3.28
lux
# Out:
# {'health': 2037,
#  'mana': 1104,
#  'melee': 550,
#  'armor': 18.72,
#  'mana_regen': 3.28}

# %%
lux["attack_speed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 lux["attack_speed"]
#
# KeyError: 'attack_speed'

# %%
a=lux.get("attack_speed",0)
a
# Out:
# 0

# %%
#딕셔너리에 키가 있는지 확인하기
'health' in lux
# Out:
# True

# %%
2037 in lux
# Out:
# False

# %%
a=input().split()
b=input().split()

dict(zip(a,b))
# Out:
# {'health': '573', 'mana': '308'}
