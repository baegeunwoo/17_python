# %%
# 불과 비교 연산자 사용하기
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
# 비교 연산자
3 > 1
# Out:
# True

# %%
# 숫자 같은지 다른지
print(10 == 10)
print(10 != 5)
# Out:
# True
# True

# %%
print("Python" == "Python")
print("Python" == "python")
print("Python" != "python")
# Out:
# True
# False
# True

# %%
# 부등호사용하기
print(10 > 20)
print(10 < 20)
print(10 >= 10)
print(10 <= 10)
# Out:
# False
# True
# True
# True

# %%
# 객체가 같은지 다른지 비교하기

print(1 == 1.0)
print(1 is 1.0)
# Out:
# True
# False
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDT11\AppData\Local\Temp\ipykernel_15604\3916754254.py:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0)

# %%
print(True and True)
print(True or False)
# Out:
# True
# True

# %%
print(not True)
# Out:
# False

# %%
# 논리연산자와 비교연산자를 함께 사용하기
10 == 10 and 10 != 5
# Out:
# True

# %%
print(10>5 or 10 < 3)
print(not 10 > 5)
# print(not 1 is 1.0)
# Out:
# True
# False
